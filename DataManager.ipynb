# %%
import pandas as pd
import json

# %% [markdown]
# # Spotify Dataset

# %%
data = pd.read_csv("Datasets/data.csv")

# %%
countries = list(set(data.Region) - set(['global']))

# %%
with open('Datasets/countries.json', 'w') as outfile:
    json.dump(countries, outfile)

# %%
data = data.dropna()
songs = list(set(data["Track Name"]))

# %%
len(songs)
# Out:
# 11931

# %%
with open('Datasets/songs.json', 'w') as outfile:
    json.dump(songs, outfile)

# %%
db = client.music
infos = db.infos
infos.insert_one({"name":"songs_list", "value":songs})

# %% [markdown]
# ### Create list of songs

# %%
songs = pd.read_csv("Datasets/songs.csv")
len(songs)
# Out:
# 13236

# %%
songs_ids = set(data_features["id"])
len(songs_ids)
# Out:
# 4411

# %%
songs["in"] = songs["id"].map(lambda x: x in songs_ids)
songs = songs[songs["in"]]
del songs["in"]
len(songs)
# Out:
# 4411

# %%
songs.to_csv("Datasets/filteredSongs.csv", index=False)

# %% [markdown]
# ## Importing data in MongoDB

# %%
data_features = pd.read_csv("Datasets/ranking_weekly_top100.csv")

# %%
data_features["id"] = data_features["URL"].map(lambda x: x.split("/")[-1])
data_features["Date"] = data_features["Week"].map(lambda x: x.split("/")[1])

# %%
data_features
# Out:
#        Region                   Week  \
# 0          ar  2016-12-26/2017-01-01
# 1          ar  2016-12-26/2017-01-01
# 2          ar  2016-12-26/2017-01-01
# 3          ar  2016-12-26/2017-01-01
# 4          ar  2016-12-26/2017-01-01
# 5          ar  2016-12-26/2017-01-01
# 6          ar  2016-12-26/2017-01-01
# 7          ar  2016-12-26/2017-01-01
# 8          ar  2016-12-26/2017-01-01
# 9          ar  2016-12-26/2017-01-01
# 10         ar  2016-12-26/2017-01-01
# 11         ar  2016-12-26/2017-01-01
# 12         ar  2016-12-26/2017-01-01
# 13         ar  2016-12-26/2017-01-01
# 14         ar  2016-12-26/2017-01-01
# 15         ar  2016-12-26/2017-01-01
# 16         ar  2016-12-26/2017-01-01
# 17         ar  2016-12-26/2017-01-01
# 18         ar  2016-12-26/2017-01-01
# 19         ar  2016-12-26/2017-01-01
# 20         ar  2016-12-26/2017-01-01
# 21         ar  2016-12-26/2017-01-01
# 22         ar  2016-12-26/2017-01-01
# 23         ar  2016-12-26/2017-01-01
# 24         ar  2016-12-26/2017-01-01
# 25         ar  2016-12-26/2017-01-01
# 26         ar  2016-12-26/2017-01-01
# 27         ar  2016-12-26/2017-01-01
# 28         ar  2016-12-26/2017-01-01
# 29         ar  2016-12-26/2017-01-01
# ...       ...                    ...
# 174748     uy  2017-08-14/2017-08-20
# 174749     uy  2017-08-14/2017-08-20
# 174750     uy  2017-08-14/2017-08-20
# 174751     uy  2017-08-14/2017-08-20
# 174752     uy  2017-08-14/2017-08-20
# 174753     uy  2017-08-14/2017-08-20
# 174754     uy  2017-08-14/2017-08-20
# 174755     uy  2017-08-14/2017-08-20
# 174756     uy  2017-08-14/2017-08-20
# 174757     uy  2017-08-14/2017-08-20
# 174758     uy  2017-08-14/2017-08-20
# 174759     uy  2017-08-14/2017-08-20
# 174760     uy  2017-08-14/2017-08-20
# 174761     uy  2017-08-14/2017-08-20
# 174762     uy  2017-08-14/2017-08-20
# 174763     uy  2017-08-14/2017-08-20
# 174764     uy  2017-08-14/2017-08-20
# 174765     uy  2017-08-14/2017-08-20
# 174766     uy  2017-08-14/2017-08-20
# 174767     uy  2017-08-14/2017-08-20
# 174768     uy  2017-08-14/2017-08-20
# 174769     uy  2017-08-14/2017-08-20
# 174770     uy  2017-08-14/2017-08-20
# 174771     uy  2017-08-14/2017-08-20
# 174772     uy  2017-08-14/2017-08-20
# 174773     uy  2017-08-14/2017-08-20
# 174774     uy  2017-08-14/2017-08-20
# 174775     uy  2017-08-14/2017-08-20
# 174776     uy  2017-08-14/2017-08-20
# 174777     uy  2017-08-14/2017-08-20
#
#                                                Track Name              Artist  \
# 0                                                Chantaje             Shakira
# 1                                            Vente Pa' Ca        Ricky Martin
# 2                              Reggaetón Lento (Bailemos)                CNCO
# 3                                                  Safari            J Balvin
# 4                                             Shaky Shaky        Daddy Yankee
# 5                                             Traicionera     Sebastian Yatra
# 6                                 Cuando Se Pone a Bailar              Rombai
# 7                               Otra Vez (feat. J Balvin)       Zion & Lennox
# 8                                            La Bicicleta        Carlos Vives
# 9                                  Dile Que Tu Me Quieres               Ozuna
# 10                                     Andas En Mi Cabeza       Chino & Nacho
# 11                                        Desde Esa Noche              Thalía
# 12                                         Borro Cassette              Maluma
# 13                        Gyal You A Party Animal - Remix        Charly Black
# 14                       Me Llamas (feat. Maluma) - Remix             Piso 21
# 15                                   La Bicicleta - Remix        Carlos Vives
# 16                                       DUELE EL CORAZON    Enrique Iglesias
# 17                                        Let Me Love You            DJ Snake
# 18                             La Noche No Es para Dormir         Mano Arriba
# 19                                             Vacaciones               Wisin
# 20                Rockabye (feat. Sean Paul & Anne-Marie)        Clean Bandit
# 21                                          Carnavalintro               CHANO
# 22                                             Ay Mi Dios            IAmChino
# 23                                              One Dance               Drake
# 24                                                 My Way       Calvin Harris
# 25                  Cold Water (feat. Justin Bieber & MØ)         Major Lazer
# 26                                            La Gozadera       Gente De Zona
# 27                                   Llamame Mas Temprano         Mano Arriba
# 28                                                Starboy          The Weeknd
# 29                                              Manicomio         Cosculluela
# ...                                                   ...                 ...
# 174748                                          Netflixxx            Brytiago
# 174749                    There's Nothing Holdin' Me Back        Shawn Mendes
# 174750  Back to You (feat. Bebe Rexha & Digital Farm A...     Louis Tomlinson
# 174751                                     Tengo un vicio        #TocoParaVos
# 174752                                       Baila Morena              Dame 5
# 174753                             Dile Que Tu Me Quieres               Ozuna
# 174754                           Si Tu Novio Te Deja Sola            J Balvin
# 174755                                 Andas En Mi Cabeza       Chino & Nacho
# 174756      Buscando Huellas (feat. J Balvin & Sean Paul)         Major Lazer
# 174757  Diles (feat. Arcangel, Nengo Flow, Dj Luian & ...             Farruko
# 174758                                  El Amante - Remix           Nicky Jam
# 174759                                               Mama          Jonas Blue
# 174760                                             Ayer 2            Anuel Aa
# 174761                                            Deja vu        Prince Royce
# 174762                                     Borro Cassette              Maluma
# 174763                           Something Just Like This    The Chainsmokers
# 174764            Sua Cara (feat. Anitta & Pabllo Vittar)         Major Lazer
# 174765                                      Wild Thoughts           DJ Khaled
# 174766                                         Ay Mi Dios            IAmChino
# 174767                                          Bajito No         Los Negroni
# 174768                                    Quédate Conmigo       Chyno Miranda
# 174769                                           Soy Peor           Bad Bunny
# 174770                                            Thunder     Imagine Dragons
# 174771                                        Esa Boquita           J Alvarez
# 174772                                        No Te Hagas            Jory Boy
# 174773                                        I'm the One           DJ Khaled
# 174774                                         Mala Mujer          C. Tangana
# 174775  Simple (feat. Cosculluela, Nengo Flow & Baby R...            DJ Luian
# 174776                                 More Than You Know  Axwell /\ Ingrosso
# 174777                                      Carnavalintro               CHANO
#
#                                                       URL  Streams  Position  \
# 0       https://open.spotify.com/track/6mICuAdrwEjh6Y6...   253019         1
# 1       https://open.spotify.com/track/7DM4BPaS7uofFul...   223988         2
# 2       https://open.spotify.com/track/3AEZUABDXNtecAO...   210943         3
# 3       https://open.spotify.com/track/6rQSrBHf7HlZjtc...   173865         4
# 4       https://open.spotify.com/track/58IL315gMSTD37D...   153956         5
# 5       https://open.spotify.com/track/5J1c3M4EldCfNxX...   151140         6
# 6       https://open.spotify.com/track/1MpKZi1zTXpERKw...   148369         7
# 7       https://open.spotify.com/track/3QwBODjSEzelZyV...   143004         8
# 8       https://open.spotify.com/track/0sXvAOmXgjR2QUq...   126389         9
# 9       https://open.spotify.com/track/20ZAJdsKB5IGbGj...   112012        10
# 10      https://open.spotify.com/track/5mey7CLLuFToM2P...   110395        11
# 11      https://open.spotify.com/track/1pWYnQIlqxTh5bx...   104592        12
# 12      https://open.spotify.com/track/6DUdDIRgLqCGq1D...   101535        13
# 13      https://open.spotify.com/track/1AkTW13ysu0AJrw...    99722        14
# 14      https://open.spotify.com/track/5hEM0JchdVzQ5Pw...    95010        15
# 15      https://open.spotify.com/track/7IRuf7FrdQvOGs0...    92723        16
# 16      https://open.spotify.com/track/6YZdkObH88npeKr...    91325        17
# 17      https://open.spotify.com/track/4pdPtRcBmOSQDlJ...    87926        18
# 18      https://open.spotify.com/track/3gEebOzxHpEwEli...    87033        19
# 19      https://open.spotify.com/track/3dQDid3IUNhZy1O...    86103        20
# 20      https://open.spotify.com/track/5knuzwU65gJK7IF...    76123        21
# 21      https://open.spotify.com/track/0tGAPnTFwRJA6FZ...    71963        22
# 22      https://open.spotify.com/track/6stYbAJgTszHAHZ...    71892        23
# 23      https://open.spotify.com/track/1xznGGDReH1oQq0...    71498        24
# 24      https://open.spotify.com/track/1vvNmPOiUuyCbgW...    70795        25
# 25      https://open.spotify.com/track/6DNtNfH8hXkqOX1...    70260        26
# 26      https://open.spotify.com/track/0OMRAvrtLWE2Tvc...    70028        27
# 27      https://open.spotify.com/track/5aHJug2wnupoGfg...    69382        28
# 28      https://open.spotify.com/track/5aAx2yezTd8zXrk...    65518        29
# 29      https://open.spotify.com/track/3n58u3LOFw8mITL...    64998        30
# ...                                                   ...      ...       ...
# 174775  15kZDQoTtpkya2kG8ZPJoi  2017-08-20
# 174776  3PEgB3fkiojxms35ntsTgs  2017-08-20
# 174777  0tGAPnTFwRJA6FZgYZ0BAe  2017-08-20
#
# [174778 rows x 9 columns]

# %%
len(data_features)
# Out:
# 174778

# %%
data_features = data_features.dropna()
url = list(set(data_features["URL"]))

# %%
len(url)
# Out:
# 4411

# %%
song_streams = data_features[["id","Track Name","Artist","Streams","Date","Region","Position"]].copy()
song_streams.columns = ["id.string()","n.string()","a.string()","s.string()","d.date(2006-01-02)","r.string()","p.int32()"]
#song_streams["name"] = song_streams["name"].astype('category')

#song_streams["name"] = song_streams["name"].cat.codes

# %%
song_streams.to_csv("Datasets/importData.csv", index=False)

# %% [markdown]
# # MongoDB access

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
with open('MongoDB/pass', 'r') as inFile:
    link = str(inFile.readline()[:-1])

# %%
client = MongoClient(link)

# %%
db = client.test_database

# %%
import datetime
post = {"author": "Mike", "text": "My first blog post!","tags": ["mongodb", "python", "pymongo"],"date": datetime.datetime.utcnow()}

# %%
posts = db.posts
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('5a0eaa5fd4235a166414dab5')

# %%
post = posts.find_one({"author":"Nathalie"})
post
# Out:
# {'_id': ObjectId('5a0dba0bd4235a14c4e1a139'),
#  'author': 'Nathalie',
#  'date': datetime.datetime(2017, 11, 16, 16, 17, 15, 429000),
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# ## Import Dataset in MongoDB

# %%
db = client.music
entry = db.entry
songs = db.songs

# %%
list(songs.find({"Track Name":"Despacito"},{"id":1, "Artist":1}))
# Out:
# [{'Artist': 'Tuuli',
#   '_id': ObjectId('5a101e5f1217f9c8afb8df3e'),
#   'id': '01TuWG481swg4qJw9DPJb5'}]

# %%
from datetime import datetime
from dateutil.parser import parse

# %%
datetime.strptime(data.iloc[0].Date, '%Y-%m-%d')
data.iloc[0]
# Out:
# Position                                                      1
# Track Name                                             Chantaje
# Artist                                                  Shakira
# Streams                                                  253019
# URL           https://open.spotify.com/track/6mICuAdrwEjh6Y6...
# Date                                                 2017-01-01
# Region                                                       ar
# Name: 0, dtype: object

# %%
data.to_json("Datasets/data.json")

# %%
for index, row in data.iterrows():
    entry.insert_one({"pos":row.Position, "song":row["Track Name"], "artist":row.Artist, "streams":row.Streams, "url":row.URL, "reg":row.Region})

# %%
data_features[data_features.Artist == "Shakira"].sample(5)
# Out:
#          Position  Track Name   Artist  Streams  \
# 916923         65    Chantaje  Shakira     2262
# 1648591         3    Chantaje  Shakira    23860
# 578010         28  Me Enamoré  Shakira     4009
# 1723376        60    Chantaje  Shakira    33476
# 172462         18    Chantaje  Shakira     3405
#
#                                                        URL        Date Region  \
# 916923   https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-07-17     gt
# 1648591  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-02-02     pt
# 578010   https://open.spotify.com/track/4qknM1pQz53QOyf...  2017-06-29     do
# 1723376  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-29     se
# 172462   https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-04-21     bo
#
#                              id  acousticness  danceability   ...     energy  \
# 916923   6mICuAdrwEjh6Y6lroV2Kg         0.187         0.852   ...      0.773
# 1648591  6mICuAdrwEjh6Y6lroV2Kg         0.187         0.852   ...      0.773
# 578010   4qknM1pQz53QOyfDVTjcM9         0.193         0.740   ...      0.879
# 1723376  6mICuAdrwEjh6Y6lroV2Kg         0.187         0.852   ...      0.773
# 172462   6mICuAdrwEjh6Y6lroV2Kg         0.187         0.852   ...      0.773
#
#          instrumentalness  key  liveness  loudness  mode  speechiness  \
# 916923           0.000030  8.0    0.1590    -2.921   0.0       0.0776
# 1648591          0.000030  8.0    0.1590    -2.921   0.0       0.0776
# 578010           0.000082  9.0    0.0928    -2.251   0.0       0.1050
# 1723376          0.000030  8.0    0.1590    -2.921   0.0       0.0776
# 172462           0.000030  8.0    0.1590    -2.921   0.0       0.0776
#
#            tempo  time_signature  valence
# 916923   102.034             4.0    0.907
# 1648591  102.034             4.0    0.907
# 578010   103.710             4.0    0.948
# 1723376  102.034             4.0    0.907
# 172462   102.034             4.0    0.907
#
# [5 rows x 21 columns]

# %%
song_streams = data_features[["id","Track Name","Artist","Streams","Date","Region","Position"]].copy()
song_streams.columns = ["id.string()","n.string()","a.string()","s.string()","d.date(2006-01-02)","r.string()","p.int32()"]
#song_streams["name"] = song_streams["name"].astype('category')

#song_streams["name"] = song_streams["name"].cat.codes

# %%
song_streams.to_csv("Datasets/importData.csv", index=False)

# %%
import datetime

# %%
test = db.test

# %%
entries = test.find({"date":datetime.datetime(2017, 2, 2, 0, 0)})
t = list(entries)
# Out:
# {'_id': ObjectId('5a0eccbf1217f9c8af3fae95'),
#  'date': datetime.datetime(2017, 2, 2, 0, 0),
#  'name': 'Despacito (Featuring Daddy Yankee)',
#  'region': 'ar',
#  'streams': '393283'}

# %%
t[0]
# Out:
# {'_id': ObjectId('5a0eccbf1217f9c8af3fae95'),
#  'date': datetime.datetime(2017, 2, 2, 0, 0),
#  'name': 'Despacito (Featuring Daddy Yankee)',
#  'region': 'ar',
#  'streams': '393283'}

# %% [markdown]
# # TopoJSON generation

# %%
allCountries = pd.read_csv("countries.csv")
alpha2Dict = {}
for name, alpha2 in zip(allCountries['name'], allCountries['alpha-2']):
    alpha2Dict[name] = str.lower(str(alpha2))
alpha2Dict
# Out:
# {'Afghanistan': 'af',
#  'Albania': 'al',
#  'Algeria': 'dz',
#  'American Samoa': 'as',
#  'Andorra': 'ad',
#  'Angola': 'ao',
#  'Anguilla': 'ai',
#  'Antarctica': 'aq',
#  'Antigua and Barbuda': 'ag',
#  'Argentina': 'ar',
#  'Armenia': 'am',
#  'Aruba': 'aw',
#  'Australia': 'au',
#  'Austria': 'at',
#  'Azerbaijan': 'az',
#  'Bahamas': 'bs',
#  'Bahrain': 'bh',
#  'Bangladesh': 'bd',
#  'Barbados': 'bb',
#  'Belarus': 'by',
#  'Belgium': 'be',
#  'Belize': 'bz',
#  'Benin': 'bj',
#  'Bermuda': 'bm',
#  'Bhutan': 'bt',
#  'Bolivia (Plurinational State of)': 'bo',
#  'Bonaire, Sint Eustatius and Saba': 'bq',
#  'Bosnia and Herzegovina': 'ba',
#  'Botswana': 'bw',
#  'Bouvet Island': 'bv',
#  'Brazil': 'br',
#  'British Indian Ocean Territory': 'io',
#  'Brunei Darussalam': 'bn',
#  'Bulgaria': 'bg',
#  'Burkina Faso': 'bf',
#  'Burundi': 'bi',
#  'Cabo Verde': 'cv',
#  'Cambodia': 'kh',
#  'Cameroon': 'cm',
#  'Canada': 'ca',
#  'Cayman Islands': 'ky',
#  'Central African Republic': 'cf',
#  'Chad': 'td',
#  'Chile': 'cl',
#  'China': 'cn',
#  'Christmas Island': 'cx',
#  'Cocos (Keeling) Islands': 'cc',
#  'Colombia': 'co',
#  'Comoros': 'km',
#  'Congo': 'cg',
#  'Congo (Democratic Republic of the)': 'cd',
#  'Cook Islands': 'ck',
#  'Costa Rica': 'cr',
#  'Croatia': 'hr',
#  'Cuba': 'cu',
#  'Curaçao': 'cw',
#  'Cyprus': 'cy',
#  'Czech Republic': 'cz',
#  "Côte d'Ivoire": 'ci',
#  'Denmark': 'dk',
#  'Djibouti': 'dj',
#  'Dominica': 'dm',
#  'Dominican Republic': 'do',
#  'Ecuador': 'ec',
#  'Egypt': 'eg',
#  'El Salvador': 'sv',
#  'Equatorial Guinea': 'gq',
#  'Eritrea': 'er',
#  'Estonia': 'ee',
#  'Ethiopia': 'et',
#  'Falkland Islands (Malvinas)': 'fk',
#  'Faroe Islands': 'fo',
#  'Fiji': 'fj',
#  'Finland': 'fi',
#  'France': 'fr',
#  'French Guiana': 'gf',
#  'French Polynesia': 'pf',
#  'French Southern Territories': 'tf',
#  'Gabon': 'ga',
#  'Gambia': 'gm',
#  'Georgia': 'ge',
#  'Germany': 'de',
#  'Ghana': 'gh',
#  'Gibraltar': 'gi',
#  'Greece': 'gr',
#  'Greenland': 'gl',
#  'Grenada': 'gd',
#  'Guadeloupe': 'gp',
#  'Guam': 'gu',
#  'Guatemala': 'gt',
#  'Guernsey': 'gg',
#  'Guinea': 'gn',
#  'Guinea-Bissau': 'gw',
#  'Guyana': 'gy',
#  'Haiti': 'ht',
#  'Heard Island and McDonald Islands': 'hm',
#  'Holy See': 'va',
#  'Honduras': 'hn',
#  'Hong Kong': 'hk',
#  'Hungary': 'hu',
#  'Iceland': 'is',
#  'India': 'in',
#  'Indonesia': 'id',
#  'Iran (Islamic Republic of)': 'ir',
#  'Iraq': 'iq',
#  'Ireland': 'ie',
#  'Isle of Man': 'im',
#  'Israel': 'il',
#  'Italy': 'it',
#  'Jamaica': 'jm',
#  'Japan': 'jp',
#  'Jersey': 'je',
#  'Jordan': 'jo',
#  'Kazakhstan': 'kz',
#  'Kenya': 'ke',
#  'Kiribati': 'ki',
#  "Korea (Democratic People's Republic of)": 'kp',
#  'Korea (Republic of)': 'kr',
#  'Kuwait': 'kw',
#  'Kyrgyzstan': 'kg',
#  "Lao People's Democratic Republic": 'la',
#  'Latvia': 'lv',
#  'Lebanon': 'lb',
#  'Lesotho': 'ls',
#  'Liberia': 'lr',
#  'Libya': 'ly',
#  'Liechtenstein': 'li',
#  'Lithuania': 'lt',
#  'Luxembourg': 'lu',
#  'Macao': 'mo',
#  'Macedonia (the former Yugoslav Republic of)': 'mk',
#  'Madagascar': 'mg',
#  'Malawi': 'mw',
#  'Malaysia': 'my',
#  'Maldives': 'mv',
#  'Mali': 'ml',
#  'Malta': 'mt',
#  'Marshall Islands': 'mh',
#  'Martinique': 'mq',
#  'Mauritania': 'mr',
#  'Mauritius': 'mu',
#  'Mayotte': 'yt',
#  'Mexico': 'mx',
#  'Micronesia (Federated States of)': 'fm',
#  'Moldova (Republic of)': 'md',
#  'Monaco': 'mc',
#  'Mongolia': 'mn',
#  'Montenegro': 'me',
#  'Montserrat': 'ms',
#  'Morocco': 'ma',
#  'Mozambique': 'mz',
#  'Myanmar': 'mm',
#  'Namibia': 'nan',
#  'Nauru': 'nr',
#  'Nepal': 'np',
#  'Netherlands': 'nl',
#  'New Caledonia': 'nc',
#  'New Zealand': 'nz',
#  'Nicaragua': 'ni',
#  'Niger': 'ne',
#  'Nigeria': 'ng',
#  'Niue': 'nu',
#  'Norfolk Island': 'nf',
#  'Northern Mariana Islands': 'mp',
#  'Norway': 'no',
#  'Oman': 'om',
#  'Pakistan': 'pk',
#  'Palau': 'pw',
#  'Palestine, State of': 'ps',
#  'Panama': 'pa',
#  'Papua New Guinea': 'pg',
#  'Paraguay': 'py',
#  'Peru': 'pe',
#  'Philippines': 'ph',
#  'Pitcairn': 'pn',
#  'Poland': 'pl',
#  'Portugal': 'pt',
#  'Puerto Rico': 'pr',
#  'Qatar': 'qa',
#  'Romania': 'ro',
#  'Russian Federation': 'ru',
#  'Rwanda': 'rw',
#  'Réunion': 're',
#  'Saint Barthélemy': 'bl',
#  'Saint Helena, Ascension and Tristan da Cunha': 'sh',
#  'Saint Kitts and Nevis': 'kn',
#  'Saint Lucia': 'lc',
#  'Saint Martin (French part)': 'mf',
#  'Saint Pierre and Miquelon': 'pm',
#  'Saint Vincent and the Grenadines': 'vc',
#  'Samoa': 'ws',
#  'San Marino': 'sm',
#  'Sao Tome and Principe': 'st',
#  'Saudi Arabia': 'sa',
#  'Senegal': 'sn',
#  'Serbia': 'rs',
#  'Seychelles': 'sc',
#  'Sierra Leone': 'sl',
#  'Singapore': 'sg',
#  'Sint Maarten (Dutch part)': 'sx',
#  'Slovakia': 'sk',
#  'Slovenia': 'si',
#  'Solomon Islands': 'sb',
#  'Somalia': 'so',
#  'South Africa': 'za',
#  'South Georgia and the South Sandwich Islands': 'gs',
#  'South Sudan': 'ss',
#  'Spain': 'es',
#  'Sri Lanka': 'lk',
#  'Sudan': 'sd',
#  'Suriname': 'sr',
#  'Svalbard and Jan Mayen': 'sj',
#  'Swaziland': 'sz',
#  'Sweden': 'se',
#  'Switzerland': 'ch',
#  'Syrian Arab Republic': 'sy',
#  'Taiwan, Province of China': 'tw',
#  'Tajikistan': 'tj',
#  'Tanzania, United Republic of': 'tz',
#  'Thailand': 'th',
#  'Timor-Leste': 'tl',
#  'Togo': 'tg',
#  'Tokelau': 'tk',
#  'Tonga': 'to',
#  'Trinidad and Tobago': 'tt',
#  'Tunisia': 'tn',
#  'Turkey': 'tr',
#  'Turkmenistan': 'tm',
#  'Turks and Caicos Islands': 'tc',
#  'Tuvalu': 'tv',
#  'Uganda': 'ug',
#  'Ukraine': 'ua',
#  'United Arab Emirates': 'ae',
#  'United Kingdom of Great Britain and Northern Ireland': 'gb',
#  'United States Minor Outlying Islands': 'um',
#  'United States of America': 'us',
#  'Uruguay': 'uy',
#  'Uzbekistan': 'uz',
#  'Vanuatu': 'vu',
#  'Venezuela (Bolivarian Republic of)': 've',
#  'Viet Nam': 'vn',
#  'Virgin Islands (British)': 'vg',
#  'Virgin Islands (U.S.)': 'vi',
#  'Wallis and Futuna': 'wf',
#  'Western Sahara': 'eh',
#  'Yemen': 'ye',
#  'Zambia': 'zm',
#  'Zimbabwe': 'zw',
#  'Åland Islands': 'ax'}

# %%
countryIDs = pd.read_csv("world-country-names.tsv", sep="\t")
idDict = {}
for countryID, name in zip(countryIDs['id'], countryIDs['name']):
    try:
        idDict[str(int(countryID))] = (alpha2Dict[name], name)
    except:
        print("No correspondance found for: " + name + " id: " + str(countryID))
# Out:
# No correspondance found for: Northern Cyprus id: -1
# No correspondance found for: Kosovo id: -2
# No correspondance found for: Somaliland id: -3
# No correspondance found for: Bolivia, Plurinational State of id: 68
# No correspondance found for: Virgin Islands, British id: 92
# No correspondance found for: Cape Verde id: 132
# No correspondance found for: Congo, the Democratic Republic of the id: 180
# No correspondance found for: Palestinian Territory, Occupied id: 275
# No correspondance found for: Holy See (Vatican City State) id: 336
# No correspondance found for: Iran, Islamic Republic of id: 364
# No correspondance found for: Korea, Democratic People's Republic of id: 408
# No correspondance found for: Korea, Republic of id: 410
# No correspondance found for: Moldova, Republic of id: 498
# No correspondance found for: Micronesia, Federated States of id: 583
# No correspondance found for: Macedonia, the former Yugoslav Republic of id: 807
# No correspondance found for: United Kingdom id: 826
# No correspondance found for: United States id: 840
# No correspondance found for: Virgin Islands, U.S. id: 850
# No correspondance found for: Venezuela, Bolivarian Republic of id: 862

# %%
idDict["840"] = ('us', "United States")
idDict["826"]  = ('gb', 'United Kingdom')
idDict["498"]  = ('md','Moldova')
idDict["410"]  = ('kr',"Republic of Korea")
idDict["408"]  = ('kp',"Democratic People's Republic of Korea")
idDict["807"]  = ('mk',"Macedonia (FYRO)")
idDict["862"]  = ('ve',"Venezuela")
idDict["364"]  = ('ir','Iran')
idDict["68"] = ('bo','Bolivia')
idDict["-2"] = ('xk','Kosovo')
idDict["180"]  = ('cd','Democratic Republic of Congo')
idDict["275"]  = ('ps','Palestine')
idDict["583"]  = ('fm','Micronesia')

# %%
infos[infos['alpha2'] == ""]
# Out:
#     alpha2                      arcs   id name     type
# 38                      [[218, 219]]  -99       Polygon
# 88            [[-18, 404, 405, 406]]  -99       Polygon
# 145         [[-265, -233, 554, 555]]  -99       Polygon

# %%
with open("all-geo-110m.json", "w") as out:
    json.dump(geo, out)

# %%
with open("id_dict.json", "w") as out:
    json.dump(idDict, out)
